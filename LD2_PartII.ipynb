# %% [markdown]
# #**Part II: Signals and Systems**

# %% [markdown]
# # **Written part (paper)**

# %% [markdown]
# *1. You are given two analog sinusoidal signals ruled by:*
#
# $$ x_1(t) = 19 \cos(2\pi50t) $$
# $$ x_2(t) = 19 \cos(2\pi230t)$$
#
# *a. Determine the signal $x_1[n]$ and $x_2[n]$ you would obtain after sampling $x_1(t)$ and $x_2(t)$, respectively, using a sampling frequency $Fs = 40 Hz $. (3 points)*
#
# *b. Do you consider Fs =  40 Hz an appropiate sampling frequency? If not, explain how could you sample the signals correctly and provide a value.* 5 points (2 points).

# %% [markdown]
# *2. Determine if the following system is a) linear, b) BIBO-stable, c) time-invariant.* (5 points)
#
# $$ y[n] \space =\space  T{x[n]}\space  = \space x[n+3] - x[n-3] $$

# %% [markdown]
# # **Coded part (Python)**

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# *3. Your 15-year old niece Maria is currently taking piano classes. To do so, she has had to learn notes and chordes at a deeper level, that is, understand them mathematically.*
# *Today she is practicing the major chord A-C#-E (mathematically described by the signal $x(t)$):*
#
# $$x(t) =\mathrm{sin}(880\pi \mathrm{t}) \space +\space \mathrm{sin}(1100\pi \mathrm{t})\space + \space \mathrm{sin}(1320\pi \mathrm{t}); \space\space\space\space\space where \space the\space frequencies\space of\space each\space note\space are:$$
#
# $f_A = 440 Hz$, $\space$ $f_C = 550 Hz$  $\space$ and $\space$ $f_E = 660 Hz$
#
# *Maria is recording herself in order to keep track of her improvements; however, when she listens to her recorded file, the sound seems to be quiet different to what she hears while playing the instrument.*
#
# *She asks you for help and when you check the default parameters of the audio recorder program, you notice that the sampling frequency Fs is set to 100 Hz.*
#
# *a. Determine whether the signal is periodic. If so, then calculate their fundamental period.* (3 points)

# %%
##It is periodic
##To obtain the fundamental period of the signal we musth obtain the M.C.M of the frequencies.
##It is 
Fp = 5*2*2*2*3*5*11 ;Fp
# Out:
# 6600

# %% [markdown]
# *b. Plot the signal that stands for the major chord A-C#-E in a continuous time domain. Use .plot() for the continuous versions. Use .xlabel and .ylabel to identify the labels of your figure. Propose an adequate interval for the time domain so you can see all the features of the signal x(t), that is, plot at least 2 periods of the signal.* (3 points)
#
# *Hint:*
#
# *- For the definition of your time interval domain, make use of the fundamental period and use a step that is the inverse of the LCM of the given frequencies.*

# %%
t = np.arange(0,4,0.01)
x = np.sin(880*np.pi*t) + np.sin(1100*np.pi*t)+np.sin(1320*np.pi*t)
plt.figure(figsize=(10,5))
plt.plot(t,x,linewidth=2)
plt.grid()
plt.xlabel('time(s)')
plt.ylabel('Major Chord A-C#-E')
# Out:
# Text(0, 0.5, 'Major Chord A-C#-E')

# %% [markdown]
# *c. Sample the signal x(t) using a sampling frequency Fs equal to 1200 Hz and plot this discrete version of x(t) with the continuous version x(t) in the same figure so you can compare both signals visually.* *What can you tell from the graffic comparison?* (2 points)

# %% [markdown]
# *d. Prove that the Fs = 1200 Hz used to obtain x[n] is not in line with the Nyquist criterion.* (1 point)

# %% [markdown]
# *e. Propose an appropiate sampling frequency value to set in the audio recorder program so you can obtain a representative form of the original signal.* (1 point)
